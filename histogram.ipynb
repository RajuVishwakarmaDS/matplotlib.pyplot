# %%
# import required library
import matplotlib.pyplot as plt

x=[55,62,45,21,22,34]
bins=[10,20,30,40,50]
plt.hist(x,bins,rwidth=0.5,color='b',alpha=0.5,label='population')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
